# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df=sns.load_dataset('titanic')

# %%
df1 = pd.DataFrame(df)

# %%
df1.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df1.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
sns.displot(x=df1['age'],bins=10,kde= True) #Distribution plot

# %%
sns.jointplot(x=df1['age'],y=df1['fare'])

# %%
sns.rugplot(x=df1['age'],y=df1['fare'])
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.barplot(x=df1['sex'],y = df1['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.countplot(x=df1['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x=df1['sex'],y = df1['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x=df1['sex'],y = df1['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
df1['sex_encoded']=df1['sex'].map({'male':0,'female':1})

# %%
sns.heatmap(df1[['survived','pclass','age','fare','sibsp','parch','sex_encoded']].corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.clustermap(df1[['survived','pclass','age','fare','sibsp','parch','sex_encoded']].corr(),annot=True)

# %%
sns.stripplot(x=df1['sex'],y =df1['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(x=df1['sex'],y =df1['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>
